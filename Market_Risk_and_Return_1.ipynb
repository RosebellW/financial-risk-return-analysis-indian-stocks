# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns # for making plots with seaborn
color = sns.color_palette()
import sklearn.metrics as metrics

import warnings
warnings.filterwarnings("ignore")

# %%
stock_prices = pd.read_csv('/content/Market+Risk+Dataset.csv')

# %%
#Glimpse of Data
stock_prices.head()
# Out:
#          Date  Infosys  Indian Hotel  Mahindra & Mahindra  Axis Bank  SAIL  \
# 0  31-03-2014      264            69                  455        263    68
# 1  07-04-2014      257            68                  458        276    70
# 2  14-04-2014      254            68                  454        270    68
# 3  21-04-2014      253            68                  488        283    68
# 4  28-04-2014      256            65                  482        282    63
#
#    Shree Cement  Sun Pharma  Jindal Steel  Idea Vodafone  Jet Airways
# 0          5543         555           298             83          278
# 1          5728         610           279             84          303
# 2          5649         607           279             83          280
# 3          5692         604           274             83          282
# 4          5582         611           238             79          243

# %%
stock_prices.columns = stock_prices.columns.str.replace(' ', '_')

# %%
#Glimpse of Data
stock_prices.head()
# Out:
#          Date  Infosys  Indian_Hotel  Mahindra_&_Mahindra  Axis_Bank  SAIL  \
# 0  31-03-2014      264            69                  455        263    68
# 1  07-04-2014      257            68                  458        276    70
# 2  14-04-2014      254            68                  454        270    68
# 3  21-04-2014      253            68                  488        283    68
# 4  28-04-2014      256            65                  482        282    63
#
#    Shree_Cement  Sun_Pharma  Jindal_Steel  Idea_Vodafone  Jet_Airways
# 0          5543         555           298             83          278
# 1          5728         610           279             84          303
# 2          5649         607           279             83          280
# 3          5692         604           274             83          282
# 4          5582         611           238             79          243

# %%
print('The number of rows (observations) is',stock_prices.shape[0],'\n''The number of columns (variables) is',stock_prices.shape[1])
# Out:
# The number of rows (observations) is 314
# The number of columns (variables) is 11

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314 entries, 0 to 313
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 314 non-null    object
#  1   Infosys              314 non-null    int64
#  2   Indian_Hotel         314 non-null    int64
#  3   Mahindra_&_Mahindra  314 non-null    int64
#  4   Axis_Bank            314 non-null    int64
#  5   SAIL                 314 non-null    int64
#  6   Shree_Cement         314 non-null    int64
#  7   Sun_Pharma           314 non-null    int64
#  8   Jindal_Steel         314 non-null    int64
#  9   Idea_Vodafone        314 non-null    int64
#  10  Jet_Airways          314 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 27.1+ KB

# %%
stock_prices.describe()
# Out:
#           Infosys  Indian_Hotel  Mahindra_&_Mahindra   Axis_Bank        SAIL  \
# count  314.000000    314.000000           314.000000  314.000000  314.000000
# mean   511.340764    114.560510           636.678344  540.742038   59.095541
# std    135.952051     22.509732           102.879975  115.835569   15.810493
# min    234.000000     64.000000           284.000000  263.000000   21.000000
# 25%    424.000000     96.000000           572.000000  470.500000   47.000000
# 50%    466.500000    115.000000           625.000000  528.000000   57.000000
# 75%    630.750000    134.000000           678.000000  605.250000   71.750000
# max    810.000000    157.000000           956.000000  808.000000  104.000000
#
#        Shree_Cement   Sun_Pharma  Jindal_Steel  Idea_Vodafone  Jet_Airways
# count    314.000000   314.000000    314.000000     314.000000   314.000000
# mean   14806.410828   633.468153    147.627389      53.713376   372.659236
# ...

# %% [markdown]
# #### Lets us plot & see price trend over time for different companies

# %%
plt.figure(figsize = (10, 8))
stock_prices['dates'] = [pd.to_datetime(d) for d in stock_prices['Date']]
plt.scatter(stock_prices['dates'], stock_prices['Infosys'], edgecolors='b', color = 'lightblue')
plt.xlabel('Year')
plt.ylabel('Infosys')
plt.title('Infosys over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
stock_prices['dates'] = [pd.to_datetime(d) for d in stock_prices['Date']]
plt.scatter(stock_prices['dates'], stock_prices['Indian_Hotel'], edgecolors='b', color = 'gray')
plt.xlabel('Year')
plt.ylabel('Indian_Hotel')
plt.title('Indian_Hotel over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
stock_prices['dates'] = [pd.to_datetime(d) for d in stock_prices['Date']]
plt.scatter(stock_prices['dates'], stock_prices['Mahindra_&_Mahindra'], edgecolors='b', color = 'brown')
plt.xlabel('Year')
plt.ylabel('Mahindra_&_Mahindra')
plt.title('Mahindra_&_Mahindra over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
stock_prices['dates'] = [pd.to_datetime(d) for d in stock_prices['Date']]
plt.scatter(stock_prices['dates'], stock_prices['Axis_Bank'], edgecolors='b', color = 'blue')
plt.xlabel('Year')
plt.ylabel('Axis_Bank')
plt.title('Axis_Bank over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
stock_prices['dates'] = [pd.to_datetime(d) for d in stock_prices['Date']]
plt.scatter(stock_prices['dates'], stock_prices['SAIL'], edgecolors='b', color = 'green')
plt.xlabel('Year')
plt.ylabel('SAIL')
plt.title('SAIL over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
stock_prices['dates'] = [pd.to_datetime(d) for d in stock_prices['Date']]
plt.scatter(stock_prices['dates'], stock_prices['Shree_Cement'], edgecolors='b', color = 'purple')
plt.xlabel('Year')
plt.ylabel('Shree_Cement')
plt.title('Shree_Cement over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
stock_prices['dates'] = [pd.to_datetime(d) for d in stock_prices['Date']]
plt.scatter(stock_prices['dates'], stock_prices['Sun_Pharma'], edgecolors='b', color = 'lightgreen')
plt.xlabel('Year')
plt.ylabel('Sun_Pharma')
plt.title('Sun_Pharma over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
stock_prices['dates'] = [pd.to_datetime(d) for d in stock_prices['Date']]
plt.scatter(stock_prices['dates'], stock_prices['Jindal_Steel'], edgecolors='b', color = 'orange')
plt.xlabel('Year')
plt.ylabel('Jindal_Steel')
plt.title('Jindal_Steel over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
stock_prices['dates'] = [pd.to_datetime(d) for d in stock_prices['Date']]
plt.scatter(stock_prices['dates'], stock_prices['Idea_Vodafone'], edgecolors='b', color = 'yellow')
plt.xlabel('Year')
plt.ylabel('Idea_Vodafone')
plt.title('Idea_Vodafone over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
stock_prices['dates'] = [pd.to_datetime(d) for d in stock_prices['Date']]
plt.scatter(stock_prices['dates'], stock_prices['Jet_Airways'], edgecolors='b', color = 'pink')
plt.xlabel('Year')
plt.ylabel('Jet_Airways')
plt.title('Jet_Airways over the years')
plt.show()

# %% [markdown]
# # Analyzing returns

# %% [markdown]
# Steps for calculating returns from prices:
# - Take logarithms
# - Take differences

# %%
stock_returns = np.log(stock_prices.drop(['Date','dates'],axis=1)).diff(axis = 0, periods = 1)

# %% [markdown]
# #### Checking the rows & columns of dataset

# %%
stock_returns.shape
# Out:
# (314, 10)

# %%
stock_returns.head()
# Out:
#     Infosys  Indian_Hotel  Mahindra_&_Mahindra  Axis_Bank      SAIL  \
# 0       NaN           NaN                  NaN        NaN       NaN
# 1 -0.026873     -0.014599             0.006572   0.048247  0.028988
# 2 -0.011742      0.000000            -0.008772  -0.021979 -0.028988
# 3 -0.003945      0.000000             0.072218   0.047025  0.000000
# 4  0.011788     -0.045120            -0.012371  -0.003540 -0.076373
#
#    Shree_Cement  Sun_Pharma  Jindal_Steel  Idea_Vodafone  Jet_Airways
# 0           NaN         NaN           NaN            NaN          NaN
# 1      0.032831    0.094491     -0.065882       0.011976     0.086112
# 2     -0.013888   -0.004930      0.000000      -0.011976    -0.078943
# 3      0.007583   -0.004955     -0.018084       0.000000     0.007117
# 4     -0.019515    0.011523     -0.140857      -0.049393    -0.148846

# %% [markdown]
# ### We now look at Means & Standard Deviations of these returns
#
# - Stock Means: Average returns that the stock is making on a week to week basis
# - Stock Standard Deviation : It is a measure of volatility meaning the more a stock's returns vary from the stock's average return, the more volatile the stock

# %% [markdown]
# #### Calculating stock means

# %%
stock_means = stock_returns.mean(axis = 0)
stock_means
# Out:
# Infosys                0.002794
# Indian_Hotel           0.000266
# Mahindra_&_Mahindra   -0.001506
# Axis_Bank              0.001167
# SAIL                  -0.003463
# Shree_Cement           0.003681
# Sun_Pharma            -0.001455
# Jindal_Steel          -0.004123
# Idea_Vodafone         -0.010608
# Jet_Airways           -0.009548
# dtype: float64

# %% [markdown]
# #### Calculating stock standard deviation

# %%
stock_sd = stock_returns.std(axis = 0)
stock_sd
# Out:
# Infosys                0.035070
# Indian_Hotel           0.047131
# Mahindra_&_Mahindra    0.040169
# Axis_Bank              0.045828
# SAIL                   0.062188
# Shree_Cement           0.039917
# Sun_Pharma             0.045033
# Jindal_Steel           0.075108
# Idea_Vodafone          0.104315
# Jet_Airways            0.097972
# dtype: float64

# %%
df = pd.DataFrame({'Average':stock_means, 'Volatility': stock_sd})
df
# Out:
#                       Average  Volatility
# Infosys              0.002794    0.035070
# Indian_Hotel         0.000266    0.047131
# Mahindra_&_Mahindra -0.001506    0.040169
# Axis_Bank            0.001167    0.045828
# SAIL                -0.003463    0.062188
# Shree_Cement         0.003681    0.039917
# Sun_Pharma          -0.001455    0.045033
# Jindal_Steel        -0.004123    0.075108
# Idea_Vodafone       -0.010608    0.104315
# Jet_Airways         -0.009548    0.097972

# %% [markdown]
# #### Let us plot & see what they say about stock prices

# %%
#plt.scatter(stock_sd, stock_means, edgecolors='r')
plot = sns.scatterplot(x=df['Volatility'], y=df['Average'])
plot.axvline(x=0.020257,linestyle='--', color = "red")
plot.axhline(y=0.000683,linestyle='--', color = "red")
plt.show()

# %% [markdown]
# Stock with a lower mean & higher standard deviation do not play a role in a portfolio that has competing stock with more returns & less risk.
# Thus for the data we have here, we are only left few stocks:
# - Ones with higher return for a comparative or lower risk are considered better

# %% [markdown]
# ## Insights and Recommendations
# 1. Highest Returns:
# • Shree Cement (0.003681) and Infosys (0.002794) delivered the highest average returns, indicating strong performance and potential for long-term growth.
#
# 2. Negative Returns:
# • Idea Vodafone (-0.010608) and Jet Airways (-0.009548) recorded the worst average returns, signaling significant underperformance.
# • Other stocks with negative returns include Jindal Steel (-0.004123), SAIL (-
# 0.003463), Sun Pharma (-0.001455), and Mahindra & Mahindra (-0.001506).
#
# 3. High Volatility (Risk):
# • Idea Vodafone (0.104315) and Jet Airways (0.097972) exhibited the highest volatility, reflecting high uncertainty and risk.
# • Jindal Steel (0.075108) and SAIL (0.062188) also showed elevated risk levels.
#
# 4. Low Volatility (Stability):
# • Infosys (0.035070), Shree Cement (0.039917), and Mahindra & Mahindra (0.040169)
# had relatively lower volatility, suggesting more stable price movements.
#
# **For Growth Investors:** Shree Cement and Infosys appear to be strong
# candidates for investment due to their positive returns and lower risk.
#
# **For Risk-Averse Investors:** Stocks with lower volatility, such as Infosys
# and Shree Cement, are preferable for stable returns.
#
# **For High-Risk Traders:** Stocks like Idea Vodafone and Jet Airways offer
# high volatility but come with significant downside risks. They may be
# suitable for speculative trading.
#
# • Avoid Underperforming Stocks: Companies with persistently negative
# returns, such as Idea Vodafone, Jet Airways, and Jindal Steel, may not be
# suitable for long-term investments unless turnaround signs emerge.
